# %% [markdown]
# # Nigerian Music scraped from Spotify - an analysis

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.read_csv("../data/nigerian-songs.csv")
df
# df.info()
# df.isnull().sum()
# df.describe()
# Out:
#                          name                         album  \
# 0                      Sparky            Mandy & The Jungle
# 1                  shuga rush  EVERYTHING YOU HEARD IS TRUE
# 2                       LITT!                         LITT!
# 3    Confident / Feeling Cool               Enjoy Your Life
# 4                  wanted you                         rare.
# ..                        ...                           ...
# 525                   Kwaroro                       Kwaroro
# 526             Concert Party                   Afro Escape
# 527                      Loko                    Applaudise
# 528                      Gift                    Applaudise
# 529                    Macoma                    Applaudise
#
#                   artist artist_top_genre  release_date  length  popularity  \
# 0          Cruel Santino  alternative r&b          2019  144000          48
# 1    Odunsi (The Engine)          afropop          2020   89488          30
# ...

# %%
top = df['artist_top_genre'].value_counts()
# top[:5]  # Les 5 premiers éléments 0 à 5
plt.figure(figsize=(10,7))
sns.barplot(x=top.index,y=top.values)
plt.xticks(rotation=45)
plt.title('Top genres',color = 'blue')
# Out:
# Text(0.5, 1.0, 'Top genres')

# %%
df = df[df['artist_top_genre'] != 'Missing']
top = df['artist_top_genre'].value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x=top.index,y=top.values)
plt.xticks(rotation=45)
plt.title('Top genres',color = 'blue')
# Out:
# Text(0.5, 1.0, 'Top genres')

# %%
df = df[(df['artist_top_genre'] == 'afro dancehall') | (df['artist_top_genre'] == 'afropop') | (df['artist_top_genre'] == 'nigerian pop')]
df = df[(df['popularity'] > 0)]
top = df['artist_top_genre'].value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x=top.index,y=top.values)
plt.xticks(rotation=45)
plt.title('Top genres',color = 'blue')
# Out:
# Text(0.5, 1.0, 'Top genres')

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
# /tmp/ipykernel_5942/3182244363.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()
# <AxesSubplot: >

# %%
sns.set_theme(style="ticks")

g = sns.jointplot(
    data=df,
    x="popularity", y="danceability", hue="artist_top_genre",
    kind="kde",
)

# %% [markdown]
# #### Important de maitriser ce type de tracé pour le clustering
# pour le clustering, vous pouvez utiliser des nuages de points pour afficher des clusters de données, donc maîtriser ce type de visualisation est très utile

# %%
sns.FacetGrid(df, hue="artist_top_genre") \
   .map(plt.scatter, "popularity", "danceability") \
   .add_legend()
